# %% [markdown]
# This is an ipython notebook for daisy drive <b> blah </b> markdown

# %% [markdown]
# Daisy Drive Simulator
#
# n — number of links; can handle up to about 7 before it takes ages
# cost1 — cost of the non-A drives
# cost2 — cost of the A drive
# P — homing efficiency, between 0 and 1
# C — repeated seeding frequency, or 0 if you don’t want repeated seeding
# drive_init — release frequency, between 0 and 1

# %%
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di # Example: di.display_html('<h3>%s:</h3>' % str, raw=True)

# This line will hide code by default when the notebook is exported as HTML
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)

# This line will add a button to toggle visibility of code blocks, for use with the HTML export version
di.display_html('''<button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>''', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>

# %%
import percache
cache = percache.Cache("cache.txt")

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
@cache
def daisy_drive(n, cost1, cost2, P, C, drive_init, t_max):
    # create file with the input parameters for the matlab function
    s = [n, cost1, cost2, P, C, drive_init, t_max]
    print s
    import csv
    with open('params.txt', 'w') as outfile:
        writer = csv.writer(outfile)
        writer.writerow(s)

    # execute matlab function (bash)
    # !rm T.txt
    # !rm Y.txt
    # !/Applications/MATLAB_R2016a.app/bin/matlab -nodesktop -nosplash -r "cd('/Users/erika/daisy_drive');simulate_applet()"

    # read in matlab output files
    from numpy import genfromtxt
    T = genfromtxt('T.txt', delimiter=',')
    Y = genfromtxt('Y.txt', delimiter=',')
    return(T,Y)

# %%
def plot(n, cost1, cost2, C, drive_init):
    fig, ax = plt.subplots(figsize=(4, 3),
                           subplot_kw={'axisbg':'#EEEEEE',
                                       'axisbelow':True})
    ax.grid(color='w', linewidth=2, linestyle='solid')
    
    if C == 1:
        C = drive_init
        
    (T,Y) = daisy_drive(n, cost1, cost2, 1, C, drive_init, 200)

    for i in range(0, n):
        if n > 1:
            Y_i = [b[i] for b in Y]
        else:
            Y_i = Y
        ax.plot(T, Y_i,lw=5, alpha=0.4)
    #ax.set_xlim(0, 10)
    #ax.set_ylim(-1.1, 1.1)
    return fig

# %%
from ipywidgets import StaticInteract, RangeWidget, RadioWidget

StaticInteract(plot,
               n=RadioWidget([1, 2, 3]),
               cost1=RadioWidget([0, 0.05, 0.1]),
               cost2=RadioWidget([0.02, 0.1, 0.4]),
               C=RadioWidget([0, 1]),
               drive_init=RadioWidget([0, 0.1, 1]) )
# Out:
# [3, 0, 0.02, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0, 0.02, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0, 0.02, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.02, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.02, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0, 0.1, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0, 0.1, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.1, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0, 0.1, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0, 0.1, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.1, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0, 0.1, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0, 0.1, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.1, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.4, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0, 0.4, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0, 0.4, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.4, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.4, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.02, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.02, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.02, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.02, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.02, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.02, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.02, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.02, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.02, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.1, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.1, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.1, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.1, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.1, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.1, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.1, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.1, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.1, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.4, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.4, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.4, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.4, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.4, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.4, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.4, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.4, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.4, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.02, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.1, 0.02, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.1, 0.02, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.02, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.02, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.1, 0.1, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.1, 0.1, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.1, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.1, 0.1, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.1, 0.1, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.1, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.1, 0.1, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.1, 0.1, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.1, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.4, 1, 0, 0, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.1, 0.4, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.1, 0.4, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.4, 1, 0, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.4, 1, 0, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0, 0.02, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0, 0.02, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.02, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0, 0.02, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0, 0.02, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.02, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0, 0.1, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0, 0.1, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.1, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0, 0.1, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0, 0.1, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.1, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0, 0.4, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0, 0.4, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.4, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0, 0.4, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0, 0.4, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0, 0.4, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.02, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.02, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.02, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.02, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.02, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.02, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.1, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.1, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.1, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.1, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.1, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.1, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.4, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.4, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.4, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.05, 0.4, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.05, 0.4, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.05, 0.4, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.1, 0.02, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.1, 0.02, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.02, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.1, 0.02, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.1, 0.02, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.02, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.1, 0.1, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.1, 0.1, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.1, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.1, 0.1, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.1, 0.1, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.1, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.1, 0.4, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.1, 0.4, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.4, 1, 0.1, 0.1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[1, 0.1, 0.4, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[2, 0.1, 0.4, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >[3, 0.1, 0.4, 1, 1, 1, 200]
# =
#                             < M A T L A B (R) >
#                   Copyright 1984-2016 The MathWorks, Inc.
#                    R2016a (9.0.0.341360) 64-bit (maci64)
#                              February 11, 2016
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
#
# 	Academic License
#
# >
#     <script type="text/javascript">
#       var mergeNodes = function(a, b) {
#         return [].slice.call(a).concat([].slice.call(b));
#       }; // http://stackoverflow.com/questions/914783/javascript-nodelist/17262552#17262552
#       function interactUpdate(div){
#          var outputs = div.getElementsByTagName("div");
#          //var controls = div.getElementsByTagName("input");
#          var controls = mergeNodes(div.getElementsByTagName("input"), div.getElementsByTagName("select"));
#          function nameCompare(a,b) {
#             return a.getAttribute("name").localeCompare(b.getAttribute("name"));
#          }
#          controls.sort(nameCompare);
#
#          var value = "";
#          for(i=0; i<controls.length; i++){
#            if((controls[i].type == "range") || controls[i].checked){
#              value = value + controls[i].getAttribute("name") + controls[i].value;
#            }
#            if(controls[i].type == "select-one"){
#              value = value + controls[i].getAttribute("name") + controls[i][controls[i].selectedIndex].value;
#            }
#          }
#
#          for(i=0; i<outputs.length; i++){
#            var name = outputs[i].getAttribute("name");
#            if(name == value){
#               outputs[i].style.display = 'block';
#            } else if(name != "controls"){
#               outputs[i].style.display = 'none';
#            }
#          }
#       }
#     </script>
#
#     <div>
#
#     <div name="C0cost10cost20.02drive_init0n1" style="display:block">
#       <img src="...">
#     </div>
#
#     <div name="C0cost10cost20.02drive_init0n2" style="display:none">
#       <img src="...">
#     </div>
#
#     <div name="C0cost10cost20.02drive_init0n3" style="display:none">
#       <img src="...">
#     </div>
#
#     <div name="C0cost10cost20.02drive_init0.1n1" style="display:none">
#       <img src="...">
#     </div>
#
#     <div name="C0cost10cost20.02drive_init0.1n2" style="display:none">
#       <img src="...">
#     </div>
#
#     <div name="C0cost10cost20.02drive_init0.1n3" style="display:none">
#       <img src="...

# %%
#plot(3, 0, 0.02, 0, 0.01)

# %%
cache.close()

# %%
# hide silly little matplotlib warning
import warnings
warnings.filterwarnings('ignore')
